# %% [markdown]
# # Notebook of Awesomeness xd
# + Jack Veith
# + 89/20/2021

# %% [markdown]
# ## Markdown Exercises
# **I am interested in learning code because of the large** *variety of things that can be created with such knowledge*
#
# **_I hope that I will be able to create softwares that people can use to streamline their lives, and also create enjoyable games for people to play_**
#
#
# 1. Best Practices
# 2. New Languages
# 3. Machine Learning
# 4. Game design related programming
# 5. OS architecture

# %% [markdown]
# ![what the kappa](https://media.giphy.com/media/kQ3FSVoJrkYWk/giphy.gif "brainsplosion")

# %% [markdown]
# ---

# %% [markdown]
# ## Jupyter Notebook Exercises

# %%
name = input(prompt="What is your name? ")
print("Hello", name, "!")
# Out:
# What is your name?  Jack Veith
# Hello Jack Veith !

# %% [markdown]
# the python input modified the name variable after I input my name.
# the program ran successfully.

# %%
# %matplotlib inline
import pandas as pd
# Load the PGH 311 Complaint data
data_url = \
"https://data.wprdc.org/datastore/dump/76fda9d0-69be-4dd5-8108-0de7907fc5a4"
complaints = pd.read_csv(data_url, parse_dates=True, index_col="CREATED_ON")
# Produce a graph that shows the number of complaints per month
complaints.resample("M").size().plot();

# %% [markdown]
# This program has created a visual representation of the number of complaints recieved per month for some unknown entity.
